# %% [markdown]
# # 04 — Results and Conclusions
#
# Summarize final results and generate figures for the report/slides.

# %%
import sys
sys.path.append('..')

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from config import FIGURES_DIR

# %matplotlib inline
sns.set_style('whitegrid')

# %% [markdown]
# ## Model Comparison Table
#
# _Load or paste results from notebook 03._

# %%
# results_df = ...

# %% [markdown]
# ## Comparison Bar Chart

# %%
# TODO: bar chart of accuracy / F1 by model
# fig.savefig(FIGURES_DIR / 'model_comparison.png', dpi=150)

# %% [markdown]
# ## Feature Importance (Tree-based Models)

# %%
# TODO: extract feature_importances_ from best tree model

# %% [markdown]
# ## Conclusions
#
# _Summarize key findings for the report._
